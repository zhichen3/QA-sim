# %%
import sys, os
sys.path.insert(0,"/home/zhi/SULI21")
import quasim as qua
import numpy as np

import matplotlib.pyplot as plt

# %%
qua = qua.QuaTel()

# %%
pos = [[0.20,0.24],[0.21,0.25]]
lam = 1.0*10**(-6)
s1 = 300.0  # 300 JY
s2 = 200.0  # 200 JY
w_f = qua.get_w_f(pos,lam)
dt = 0.01/w_f
n = int(2*(10.0/dt))
#print(n)
t = np.linspace(-1.0,1.0,10000)

# %%
num_pos = qua.get_num_photon(w_f,lam,s1,s2,t,'pos')
num_neg = qua.get_num_photon(w_f,lam,s1,s2,t,'neg')

# %%
plt.figure(figsize=(10,10))
plt.xlim([-0.3,0.3])
plt.plot(t,num_pos,label='pos')
#plt.plot(t,num_neg,label='neg')
plt.legend()

# %%
# Out:
# 8
